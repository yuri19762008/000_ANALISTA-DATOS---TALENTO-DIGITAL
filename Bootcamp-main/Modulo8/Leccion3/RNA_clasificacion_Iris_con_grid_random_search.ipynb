# %% [markdown]
# # RNA para Clasificación del Iris
#
# Demo paso a paso de una red neuronal artificial en Keras para clasificar especies de flores del dataset Iris.

# %% [markdown]
# ## 1. Importar librerías
#
# En este paso cargamos todas las librerías necesarias para el experimento.

# %%
# 1. Importar librerías
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, f1_score

from tensorflow import keras
from tensorflow.keras import layers

# Fijar semilla para reproducibilidad
SEED = 42
np.random.seed(SEED)
import tensorflow as tf
tf.random.set_seed(SEED)

# %% [markdown]
# ## 2. Cargar dataset Iris
#
# 1. Cargamos el dataset Iris desde `sklearn`.
# 2. Separamos las variables de entrada `X` (características) y la variable objetivo `y` (clase de flor).
# 3. Mostramos forma de los datos y nombres de clases.

# %%
# 2. Cargar dataset Iris
data = load_iris()
X = data.data  # 4 características: largo/alto de sépalos y pétalos
y = data.target  # 3 clases: 0=setosa, 1=versicolor, 2=virginica

print("Forma de X:", X.shape)
print("Clases:", data.target_names)
print("Primeras 5 etiquetas:", y[:5])
# Out:
# Forma de X: (150, 4)
# Clases: ['setosa' 'versicolor' 'virginica']
# Primeras 5 etiquetas: [0 0 0 0 0]

# %% [markdown]
# ## 3. Separar entrenamiento y validación
#
# 1. Dividimos los datos en conjunto de entrenamiento (80 %) y validación (20 %).
# 2. Usamos `stratify=y` para mantener la misma proporción de clases en ambos conjuntos.

# %%
# 3. Separar entrenamiento y validación
X_train, X_val, y_train, y_val = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=SEED,
    stratify=y
)

print("Entrenamiento:", X_train.shape, y_train.shape)
print("Validación:", X_val.shape, y_val.shape)
# Out:
# Entrenamiento: (120, 4) (120,)
# Validación: (30, 4) (30,)

# %% [markdown]
# ## 4. Estandarizar variables de entrada
#
# 1. Estandarizamos las características para que tengan media 0 y desvío estándar 1.
# 2. Ajustamos el `StandardScaler` solo con datos de entrenamiento y aplicamos la misma transformación a validación.
#
# Interpretación: esto ayuda a que la red neuronal entrene mejor porque todas las variables quedan en escalas comparables.

# %%
# 4. Estandarizar variables de entrada
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %% [markdown]
# ## 5. Definir una función para construir el modelo
#
# 1. Creamos la función `build_model` que recibe la dimensión de entrada y el número de clases.
# 2. La red tiene:
#    - Capa de entrada según número de características.
#    - Capa oculta densa de 16 neuronas con activación `relu`.
#    - Capa oculta densa de 8 neuronas con activación `relu`.
#    - Capa de salida de 3 neuronas con `softmax` (clasificación multiclase).
# 3. Compilamos el modelo con optimizador `adam` y pérdida `sparse_categorical_crossentropy`.

# %%
# 5. Definir función para construir el modelo

def build_model(input_dim, n_classes):
    model = keras.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(16, activation="relu"),
        layers.Dense(8, activation="relu"),
        layers.Dense(n_classes, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# Crear el modelo
model = build_model(input_dim=X_train.shape[1], n_classes=3)
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 243 (972.00 B)
#  Trainable params: 243 (972.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 6. Entrenar el modelo
#
# 1. Entrenamos el modelo durante 40 épocas con `batch_size=16`.
# 2. Usamos el conjunto de validación para monitorear `val_loss` y `val_accuracy`.
# 3. Guardamos el historial de entrenamiento en la variable `history` para graficar métricas luego.

# %%
# 6. Entrenar el modelo
history = model.fit(
    X_train,
    y_train,
    epochs=40,
    batch_size=16,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.1917 - loss: 1.4059 - val_accuracy: 0.2000 - val_loss: 1.3518
# Epoch 2/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2583 - loss: 1.2868 - val_accuracy: 0.2333 - val_loss: 1.2452
# Epoch 3/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3250 - loss: 1.1852 - val_accuracy: 0.3333 - val_loss: 1.1533
# Epoch 4/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3667 - loss: 1.0990 - val_accuracy: 0.4667 - val_loss: 1.0784
# Epoch 5/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4500 - loss: 1.0314 - val_accuracy: 0.5000 - val_loss: 1.0212
# Epoch 6/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5083 - loss: 0.9778 - val_accuracy: 0.5333 - val_loss: 0.9746
# Epoch 7/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5417 - loss: 0.9334 - val_accuracy: 0.5333 - val_loss: 0.9338
# Epoch 8/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5333 - loss: 0.8938 - val_accuracy: 0.6333 - val_loss: 0.8969
# Epoch 9/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5667 - loss: 0.8570 - val_accuracy: 0.6333 - val_loss: 0.8627
# Epoch 10/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6000 - loss: 0.8217 - val_accuracy: 0.7333 - val_loss: 0.8301
# Epoch 11/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6417 - loss: 0.7882 - val_accuracy: 0.7000 - val_loss: 0.7990
# Epoch 12/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6500 - loss: 0.7561 - val_accuracy: 0.6333 - val_loss: 0.7680
# Epoch 13/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6500 - loss: 0.7246 - val_accuracy: 0.6667 - val_loss: 0.7369
# Epoch 14/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6750 - loss: 0.6933 - val_accuracy: 0.6667 - val_loss: 0.7065
# Epoch 15/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7000 - loss: 0.6623 - val_accuracy: 0.6667 - val_loss: 0.6760
# Epoch 16/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6917 - loss: 0.6322 - val_accuracy: 0.6667 - val_loss: 0.6473
# Epoch 17/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7000 - loss: 0.6042 - val_accuracy: 0.7000 - val_loss: 0.6204
# Epoch 18/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7083 - loss: 0.5778 - val_accuracy: 0.7000 - val_loss: 0.5957
# Epoch 19/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7083 - loss: 0.5533 - val_accuracy: 0.7000 - val_loss: 0.5723
# Epoch 20/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7167 - loss: 0.5312 - val_accuracy: 0.7000 - val_loss: 0.5510
# Epoch 21/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7333 - loss: 0.5111 - val_accuracy: 0.7000 - val_loss: 0.5323
# Epoch 22/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.4931 - val_accuracy: 0.7000 - val_loss: 0.5154
# Epoch 23/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.4768 - val_accuracy: 0.7333 - val_loss: 0.5002
# Epoch 24/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7750 - loss: 0.4621 - val_accuracy: 0.7333 - val_loss: 0.4865
# Epoch 25/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7750 - loss: 0.4484 - val_accuracy: 0.7667 - val_loss: 0.4742
# Epoch 26/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7917 - loss: 0.4357 - val_accuracy: 0.7667 - val_loss: 0.4630
# Epoch 27/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - loss: 0.4236 - val_accuracy: 0.7667 - val_loss: 0.4525
# Epoch 28/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8250 - loss: 0.4121 - val_accuracy: 0.7667 - val_loss: 0.4425
# Epoch 29/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8333 - loss: 0.4011 - val_accuracy: 0.7667 - val_loss: 0.4329
# Epoch 30/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8333 - loss: 0.3904 - val_accuracy: 0.7667 - val_loss: 0.4237
# Epoch 31/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8583 - loss: 0.3801 - val_accuracy: 0.7667 - val_loss: 0.4147
# Epoch 32/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8750 - loss: 0.3699 - val_accuracy: 0.7667 - val_loss: 0.4058
# Epoch 33/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8750 - loss: 0.3599 - val_accuracy: 0.7667 - val_loss: 0.3972
# Epoch 34/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8833 - loss: 0.3502 - val_accuracy: 0.8000 - val_loss: 0.3888
# Epoch 35/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8833 - loss: 0.3405 - val_accuracy: 0.8000 - val_loss: 0.3805
# Epoch 36/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8833 - loss: 0.3311 - val_accuracy: 0.8000 - val_loss: 0.3726
# Epoch 37/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8833 - loss: 0.3218 - val_accuracy: 0.8000 - val_loss: 0.3647
# Epoch 38/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8833 - loss: 0.3128 - val_accuracy: 0.8000 - val_loss: 0.3570
# Epoch 39/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8833 - loss: 0.3040 - val_accuracy: 0.8000 - val_loss: 0.3495
# Epoch 40/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8833 - loss: 0.2955 - val_accuracy: 0.8000 - val_loss: 0.3423

# %% [markdown]
# ## 7. Graficar curvas de entrenamiento
#
# 1. Graficamos la función de pérdida (loss) en entrenamiento y validación.
# 2. Graficamos la exactitud (accuracy) en entrenamiento y validación.
#
# Interpretación: si la pérdida de entrenamiento baja pero la de validación sube, puede haber sobreajuste.

# %%
# 7. Graficar curvas de entrenamiento

def plot_history(history):
    plt.figure(figsize=(10, 4))

    # Pérdida
    plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"], label="train")
    plt.plot(history.history["val_loss"], label="val")
    plt.title("Pérdida")
    plt.xlabel("Época")
    plt.ylabel("Loss")
    plt.legend()

    # Exactitud
    plt.subplot(1, 2, 2)
    plt.plot(history.history["accuracy"], label="train")
    plt.plot(history.history["val_accuracy"], label="val")
    plt.title("Exactitud")
    plt.xlabel("Época")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)

# %% [markdown]
# ## 8. Evaluar el modelo en el conjunto de validación
#
# 1. Evaluamos el modelo con `model.evaluate` sobre `X_val, y_val`.
# 2. Obtenemos la pérdida (`loss`) y la exactitud (`accuracy`) finales en validación.

# %%
# 8. Evaluar el modelo en validación
loss, accuracy = model.evaluate(X_val, y_val, verbose=0)
print(f"Pérdida en validación: {loss:.4f}")
print(f"Exactitud en validación: {accuracy:.4f}")
# Out:
# Pérdida en validación: 0.3423
# Exactitud en validación: 0.8000

# %% [markdown]
# ## 9. Predicciones, métricas y matriz de confusión
#
# 1. Obtenemos probabilidades de cada clase con `model.predict`.
# 2. Convertimos las probabilidades a etiquetas predichas usando `argmax`.
# 3. Calculamos `classification_report`, `f1_score` promedio y la matriz de confusión.
# 4. Graficamos la matriz de confusión con etiquetas de clases.
#
# Mini–ejemplo de interpretación de `softmax`:
# - Si la salida es `[0.1, 0.7, 0.2]`, interpretamos 10 %, 70 % y 20 % de probabilidad para cada clase y elegimos la clase con probabilidad máxima (segunda clase).

# %%
# 9. Predicciones y métricas

# 9.1 Obtener probabilidades y clases predichas
y_proba = model.predict(X_val)
y_pred = np.argmax(y_proba, axis=1)

# 9.2 Métricas de clasificación
print("Reporte de clasificación:")
print(classification_report(y_val, y_pred, target_names=data.target_names))

macro_f1 = f1_score(y_val, y_pred, average="macro")
print(f"F1 macro: {macro_f1:.4f}")

# 9.3 Matriz de confusión
cm = confusion_matrix(y_val, y_pred)

plt.figure(figsize=(4, 4))
plt.imshow(cm, cmap="Blues")
plt.colorbar()
plt.xticks(range(3), data.target_names, rotation=45)
plt.yticks(range(3), data.target_names)
plt.xlabel("Etiqueta predicha")
plt.ylabel("Etiqueta real")
plt.title("Matriz de confusión")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center", color="black")

plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002258F76FCE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      0.40      0.57        10
#    virginica       0.62      1.00      0.77        10
#
#     accuracy                           0.80        30
#    macro avg       0.88      0.80      0.78        30
# weighted avg       0.88      0.80      0.78        30
#
# F1 macro: 0.7802

# %% [markdown]
# ## 10. Guardar y cargar el modelo entrenado
#
# 1. Guardamos el modelo entrenado en disco para reutilizarlo sin reentrenar.
# 2. Cargamos el modelo desde el archivo y comprobamos que mantiene su rendimiento.
#
# Interpretación: `model.save` almacena arquitectura, pesos y configuración; `load_model` permite volver a usar el modelo más adelante para nuevas predicciones.

# %%
# 10. Guardar y cargar el modelo entrenado

# 10.1 Guardar el modelo en disco
model.save("modelo_iris_rna.keras")
print("Modelo guardado en 'modelo_iris_rna.keras'")

# 10.2 Cargar el modelo desde disco
modelo_cargado = keras.models.load_model("modelo_iris_rna.keras")

# Verificar que el modelo cargado funciona
loss_loaded, acc_loaded = modelo_cargado.evaluate(X_val, y_val, verbose=0)
print(f"Exactitud del modelo cargado en validación: {acc_loaded:.4f}")
# Out:
# Modelo guardado en 'modelo_iris_rna.keras'
# Exactitud del modelo cargado en validación: 0.8000

# %% [markdown]
# ## 11. Predicción para un nuevo ejemplo
#
# 1. Definimos manualmente las características de una nueva flor.
# 2. Aplicamos el mismo escalado usado en el entrenamiento.
# 3. Obtenemos las probabilidades `softmax` para cada clase.
# 4. Convertimos esas probabilidades en una clase predicha y mostramos el nombre de la especie.
#
# Mini–ejemplo: si la salida del `softmax` es `[0.95, 0.04, 0.01]`, interpretamos 95 %, 4 % y 1 % de probabilidad para cada clase y elegimos la clase con probabilidad máxima.

# %%
# 11. Predicción para un nuevo ejemplo

# 11.1 Definir una flor de ejemplo (valores típicos de setosa)
# [sepal_length, sepal_width, petal_length, petal_width]
nueva_flor = np.array([[5.1, 3.5, 1.4, 0.2]])

# 11.2 Aplicar el mismo escalado que al entrenamiento
nueva_flor_escalada = scaler.transform(nueva_flor)

# 11.3 Obtener probabilidades de clase
y_proba_nueva = model.predict(nueva_flor_escalada)
print("Probabilidades softmax:", y_proba_nueva)

# 11.4 Convertir a clase predicha y mostrar nombre
clase_predicha = np.argmax(y_proba_nueva, axis=1)[0]
nombre_clase = data.target_names[clase_predicha]

print(f"Clase predicha: {clase_predicha} -> {nombre_clase}")
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002258F76FCE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Probabilidades softmax: [[0.9838304  0.01299433 0.00317531]]
# Clase predicha: 0 -> setosa

# %% [markdown]
# ## 12. Mejorar entrenamiento con EarlyStopping
#
# 1. Usamos `EarlyStopping` para detener el entrenamiento cuando la pérdida de validación deje de mejorar.
# 2. Esto ayuda a evitar sobreentrenamiento y suele dejar el modelo en el punto de mejor `val_loss`.
# 3. Volvemos a entrenar un nuevo modelo desde cero usando este callback.

# %%
# 12. Mejorar entrenamiento con EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping

# 12.1 Crear un nuevo modelo desde cero
model_es = build_model(input_dim=X_train.shape[1], n_classes=3)

# 12.2 Definir callback de EarlyStopping
early_stop = EarlyStopping(
    monitor="val_loss",      # métrica a monitorear
    patience=5,               # número de épocas sin mejora antes de parar
    restore_best_weights=True # restaurar los mejores pesos obtenidos
)

# 12.3 Entrenar con EarlyStopping
history_es = model_es.fit(
    X_train,
    y_train,
    epochs=100,               # ponemos un máximo alto
    batch_size=16,
    validation_data=(X_val, y_val),
    callbacks=[early_stop],
    verbose=1
)

# 12.4 Evaluar modelo con EarlyStopping
loss_es, acc_es = model_es.evaluate(X_val, y_val, verbose=0)
print(f"Pérdida en validación (ES): {loss_es:.4f}")
print(f"Exactitud en validación (ES): {acc_es:.4f}")
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.2833 - loss: 1.0450 - val_accuracy: 0.4667 - val_loss: 1.0180
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4667 - loss: 1.0032 - val_accuracy: 0.5000 - val_loss: 0.9818
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6583 - loss: 0.9681 - val_accuracy: 0.6333 - val_loss: 0.9506
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6917 - loss: 0.9358 - val_accuracy: 0.7000 - val_loss: 0.9201
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7250 - loss: 0.9034 - val_accuracy: 0.7667 - val_loss: 0.8893
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7250 - loss: 0.8698 - val_accuracy: 0.7333 - val_loss: 0.8577
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.8348 - val_accuracy: 0.7000 - val_loss: 0.8251
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.7979 - val_accuracy: 0.7333 - val_loss: 0.7891
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7750 - loss: 0.7572 - val_accuracy: 0.7333 - val_loss: 0.7508
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8083 - loss: 0.7132 - val_accuracy: 0.7333 - val_loss: 0.7105
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9750 - loss: 0.0842 - val_accuracy: 0.9667 - val_loss: 0.1147
# Pérdida en validación (ES): 0.1147
# Exactitud en validación (ES): 0.9667

# %% [markdown]
# ## 13. Comparar la RNA con un modelo clásico (Regresión Logística)
#
# 1. Entrenamos una Regresión Logística sobre los mismos datos escalados.
# 2. Comparamos la exactitud y el F1 macro entre la RNA con EarlyStopping y la Regresión Logística.
# 3. Esto nos sirve como referencia para saber si la RNA está rindiendo tan bien como un modelo clásico fuerte en este dataset.

# %%
# 13. Comparar con Regresión Logística
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# 13.1 Entrenar Regresión Logística
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)

# 13.2 Evaluar en validación
y_pred_lr = log_reg.predict(X_val)
acc_lr = accuracy_score(y_val, y_pred_lr)
macro_f1_lr = f1_score(y_val, y_pred_lr, average="macro")

print(f"Accuracy Regresión Logística: {acc_lr:.4f}")
print(f"F1 macro Regresión Logística: {macro_f1_lr:.4f}")

# 13.3 Comparar con la RNA (EarlyStopping)
y_proba_es = model_es.predict(X_val)
y_pred_es = np.argmax(y_proba_es, axis=1)

macro_f1_es = f1_score(y_val, y_pred_es, average="macro")
print(f"F1 macro RNA (EarlyStopping): {macro_f1_es:.4f}")
# Out:
# Accuracy Regresión Logística: 0.9333
# F1 macro Regresión Logística: 0.9333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# F1 macro RNA (EarlyStopping): 0.9666

# %% [markdown]
# ## 14. Resumen de mejoras aplicadas
#
# 1. Agregamos `EarlyStopping` para detener el entrenamiento cuando la validación deja de mejorar.
# 2. Comparamos el desempeño de la RNA contra Regresión Logística en el mismo conjunto de validación.
# 3. Con estos pasos puedes:
#    - Ajustar arquitectura e hiperparámetros de la RNA.
#    - Ver si tiene sentido usar una RNA o si un modelo clásico ya alcanza un rendimiento similar o mejor.

# %% [markdown]
# ## 15. Preparar modelo Keras para usar con GridSearchCV y RandomizedSearchCV
#
# 1. Usaremos `KerasClassifier` de `scikeras.wrappers` para poder integrar nuestra red neuronal con las herramientas de búsqueda de hiperparámetros de `sklearn`.
# 2. Definiremos una función `create_model` que acepte hiperparámetros como argumentos (neuronal de la capa oculta, tasa de aprendizaje, etc.).
# 3. Luego construiremos un estimador compatible con `sklearn` a partir de esa función.

# %%
# 15. Preparar wrapper de Keras para sklearn

# !pip install -q scikeras

from scikeras.wrappers import KerasClassifier
from tensorflow.keras.optimizers import Adam

# 15.1 Función creadora de modelo con hiperparámetros

def create_model(units_1=16, units_2=8, learning_rate=0.001):
    model = keras.Sequential([
        layers.Input(shape=(X_train.shape[1],)),
        layers.Dense(units_1, activation="relu"),
        layers.Dense(units_2, activation="relu"),
        layers.Dense(3, activation="softmax")
    ])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# 15.2 Crear el estimador KerasClassifier
keras_clf = KerasClassifier(
    model=create_model,
    epochs=40,
    batch_size=16,
    verbose=0
)

# %% [markdown]
# ## 16. GridSearchCV: búsqueda exhaustiva de hiperparámetros
#
# 1. Definimos una rejilla pequeña de hiperparámetros a explorar: neuronas en la primera y segunda capa oculta, `batch_size` y `epochs`.
# 2. Usamos `GridSearchCV` con validación cruzada estratificada para evaluar cada combinación.
# 3. Guardamos los mejores hiperparámetros encontrados y su `mean_test_score`.
#
# Nota: para que el tiempo de ejecución sea razonable en Iris, usamos una rejilla pequeña y `cv=3`.

# %%
# 16. GridSearchCV
from sklearn.model_selection import GridSearchCV

# 16.1 Definir rejilla de hiperparámetros
param_grid = {
    "model__units_1": [8, 16],
    "model__units_2": [4, 8],
    "batch_size": [8, 16],
    "epochs": [40, 80]
}

# 16.2 Configurar GridSearchCV
grid_search = GridSearchCV(
    estimator=keras_clf,
    param_grid=param_grid,
    cv=3,
    scoring="accuracy",
    n_jobs=-1
)

# 16.3 Ejecutar búsqueda (toma algunos minutos según recursos)
grid_search.fit(X_train, y_train)

print("Mejores hiperparámetros (GridSearchCV):")
print(grid_search.best_params_)
print(f"Mejor accuracy medio en CV: {grid_search.best_score_:.4f}")
# Out:
# Mejores hiperparámetros (GridSearchCV):
# {'batch_size': 16, 'epochs': 80, 'model__units_1': 16, 'model__units_2': 8}
# Mejor accuracy medio en CV: 0.9583

# %% [markdown]
# ## 17. RandomizedSearchCV: búsqueda aleatoria de hiperparámetros
#
# 1. Definimos distribuciones/valores posibles para los mismos hiperparámetros, agregando opciones adicionales.
# 2. Usamos `RandomizedSearchCV` para muestrear un número limitado de combinaciones (`n_iter`).
# 3. Comparamos el mejor resultado encontrado por RandomizedSearchCV con el de GridSearchCV.

# %%
# 17. RandomizedSearchCV
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# 17.1 Definir espacio de búsqueda aleatorio
param_distributions = {
    "model__units_1": randint(8, 33),      # entre 8 y 32
    "model__units_2": randint(4, 17),      # entre 4 y 16
    "batch_size": [8, 16, 32],
    "epochs": [40, 80, 120],
    "model__learning_rate": uniform(1e-4, 9e-3)  # entre 0.0001 y 0.0091 aprox.
}

rand_search = RandomizedSearchCV(
    estimator=keras_clf,
    param_distributions=param_distributions,
    n_iter=10,
    cv=3,
    scoring="accuracy",
    n_jobs=-1,
    random_state=SEED
)

rand_search.fit(X_train, y_train)

print("Mejores hiperparámetros (RandomizedSearchCV):")
print(rand_search.best_params_)
print(f"Mejor accuracy medio en CV: {rand_search.best_score_:.4f}")
# Out:
# Mejores hiperparámetros (RandomizedSearchCV):
# {'batch_size': 16, 'epochs': 40, 'model__learning_rate': np.float64(0.008829188669457947), 'model__units_1': 19, 'model__units_2': 9}
# Mejor accuracy medio en CV: 0.9667

# %% [markdown]
# ## 18. Entrenar modelo final con los mejores hiperparámetros
#
# 1. Tomamos los mejores hiperparámetros encontrados por GridSearchCV y entrenamos un modelo final en todo el conjunto de entrenamiento.
# 2. Evaluamos este modelo final en el conjunto de validación (`X_val, y_val`).
# 3. Comparamos su desempeño con el modelo base y con la Regresión Logística entrenada antes.

# %%
best_params_grid = grid_search.best_params_

best_model = create_model(
    units_1=best_params_grid["model__units_1"],
    units_2=best_params_grid["model__units_2"],
    learning_rate=best_params_grid.get("model__learning_rate", 0.001)
)

# %%
history_best = best_model.fit(
    X_train,
    y_train,
    epochs=best_params_grid["epochs"],
    batch_size=best_params_grid["batch_size"],
    validation_data=(X_val, y_val),
    verbose=0
)

# %%
loss_best, acc_best = best_model.evaluate(X_val, y_val, verbose=0)
print(f"Accuracy modelo final (mejores hiperparámetros GridSearchCV): {acc_best:.4f}")

# Opcional: comparar con Regresión Logística si ya se entrenó antes
try:
    print(f"Accuracy Regresión Logística (antes): {acc_lr:.4f}")
except NameError:
    print("Regresión Logística no estaba definida en esta sesión.")
# Out:
# Accuracy modelo final (mejores hiperparámetros GridSearchCV): 0.9667
# Accuracy Regresión Logística (antes): 0.9333
