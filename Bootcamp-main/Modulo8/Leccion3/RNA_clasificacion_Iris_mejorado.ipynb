# %% [markdown]
# # RNA para Clasificación del Iris
#
# Demo paso a paso de una red neuronal artificial en Keras para clasificar especies de flores del dataset Iris.

# %% [markdown]
# ## 1. Importar librerías
#
# En este paso cargamos todas las librerías necesarias para el experimento.

# %%
# 1. Importar librerías
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, f1_score

from tensorflow import keras
from tensorflow.keras import layers

# Fijar semilla para reproducibilidad
SEED = 42
np.random.seed(SEED)
import tensorflow as tf
tf.random.set_seed(SEED)

# %% [markdown]
# ## 2. Cargar dataset Iris
#
# 1. Cargamos el dataset Iris desde `sklearn`.
# 2. Separamos las variables de entrada `X` (características) y la variable objetivo `y` (clase de flor).
# 3. Mostramos forma de los datos y nombres de clases.

# %%
# 2. Cargar dataset Iris
data = load_iris()
X = data.data  # 4 características: largo/alto de sépalos y pétalos
y = data.target  # 3 clases: 0=setosa, 1=versicolor, 2=virginica

print("Forma de X:", X.shape)
print("Clases:", data.target_names)
print("Primeras 5 etiquetas:", y[:5])
# Out:
# Forma de X: (150, 4)
# Clases: ['setosa' 'versicolor' 'virginica']
# Primeras 5 etiquetas: [0 0 0 0 0]

# %% [markdown]
# ## 3. Separar entrenamiento y validación
#
# 1. Dividimos los datos en conjunto de entrenamiento (80 %) y validación (20 %).
# 2. Usamos `stratify=y` para mantener la misma proporción de clases en ambos conjuntos.

# %%
# 3. Separar entrenamiento y validación
X_train, X_val, y_train, y_val = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=SEED,
    stratify=y
)

print("Entrenamiento:", X_train.shape, y_train.shape)
print("Validación:", X_val.shape, y_val.shape)
# Out:
# Entrenamiento: (120, 4) (120,)
# Validación: (30, 4) (30,)

# %% [markdown]
# ## 4. Estandarizar variables de entrada
#
# 1. Estandarizamos las características para que tengan media 0 y desvío estándar 1.
# 2. Ajustamos el `StandardScaler` solo con datos de entrenamiento y aplicamos la misma transformación a validación.
#
# Interpretación: esto ayuda a que la red neuronal entrene mejor porque todas las variables quedan en escalas comparables.

# %%
# 4. Estandarizar variables de entrada
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %% [markdown]
# ## 5. Definir una función para construir el modelo
#
# 1. Creamos la función `build_model` que recibe la dimensión de entrada y el número de clases.
# 2. La red tiene:
#    - Capa de entrada según número de características.
#    - Capa oculta densa de 16 neuronas con activación `relu`.
#    - Capa oculta densa de 8 neuronas con activación `relu`.
#    - Capa de salida de 3 neuronas con `softmax` (clasificación multiclase).
# 3. Compilamos el modelo con optimizador `adam` y pérdida `sparse_categorical_crossentropy`.

# %%
# 5. Definir función para construir el modelo

def build_model(input_dim, n_classes):
    model = keras.Sequential([
        layers.Input(shape=(input_dim,)),
        layers.Dense(16, activation="relu"),
        layers.Dense(8, activation="relu"),
        layers.Dense(n_classes, activation="softmax")
    ])

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model

# Crear el modelo
model = build_model(input_dim=X_train.shape[1], n_classes=3)
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 16)             │            80 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 243 (972.00 B)
#  Trainable params: 243 (972.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 6. Entrenar el modelo
#
# 1. Entrenamos el modelo durante 40 épocas con `batch_size=16`.
# 2. Usamos el conjunto de validación para monitorear `val_loss` y `val_accuracy`.
# 3. Guardamos el historial de entrenamiento en la variable `history` para graficar métricas luego.

# %%
# 6. Entrenar el modelo
history = model.fit(
    X_train,
    y_train,
    epochs=40,
    batch_size=16,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3000 - loss: 1.1320 - val_accuracy: 0.3333 - val_loss: 1.1216
# Epoch 2/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3083 - loss: 1.0965 - val_accuracy: 0.3333 - val_loss: 1.0966
# Epoch 3/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3583 - loss: 1.0703 - val_accuracy: 0.4333 - val_loss: 1.0748
# Epoch 4/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4167 - loss: 1.0470 - val_accuracy: 0.4667 - val_loss: 1.0530
# Epoch 5/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5333 - loss: 1.0235 - val_accuracy: 0.6000 - val_loss: 1.0306
# Epoch 6/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6083 - loss: 1.0012 - val_accuracy: 0.6333 - val_loss: 1.0088
# Epoch 7/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7000 - loss: 0.9803 - val_accuracy: 0.6667 - val_loss: 0.9882
# Epoch 8/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6917 - loss: 0.9600 - val_accuracy: 0.6667 - val_loss: 0.9679
# Epoch 9/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7083 - loss: 0.9389 - val_accuracy: 0.6667 - val_loss: 0.9469
# Epoch 10/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7083 - loss: 0.9169 - val_accuracy: 0.6667 - val_loss: 0.9245
# Epoch 11/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7000 - loss: 0.8936 - val_accuracy: 0.6667 - val_loss: 0.9009
# Epoch 12/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7000 - loss: 0.8691 - val_accuracy: 0.6667 - val_loss: 0.8762
# Epoch 13/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7000 - loss: 0.8434 - val_accuracy: 0.6667 - val_loss: 0.8504
# Epoch 14/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7000 - loss: 0.8165 - val_accuracy: 0.6667 - val_loss: 0.8239
# Epoch 15/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7083 - loss: 0.7888 - val_accuracy: 0.6667 - val_loss: 0.7969
# Epoch 16/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7083 - loss: 0.7605 - val_accuracy: 0.6667 - val_loss: 0.7698
# Epoch 17/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7167 - loss: 0.7325 - val_accuracy: 0.6667 - val_loss: 0.7433
# Epoch 18/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.7051 - val_accuracy: 0.7000 - val_loss: 0.7179
# Epoch 19/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7333 - loss: 0.6789 - val_accuracy: 0.7000 - val_loss: 0.6941
# Epoch 20/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7417 - loss: 0.6544 - val_accuracy: 0.7000 - val_loss: 0.6721
# Epoch 21/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7583 - loss: 0.6317 - val_accuracy: 0.7000 - val_loss: 0.6521
# Epoch 22/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7583 - loss: 0.6111 - val_accuracy: 0.7000 - val_loss: 0.6341
# Epoch 23/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7667 - loss: 0.5925 - val_accuracy: 0.7000 - val_loss: 0.6181
# Epoch 24/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7667 - loss: 0.5759 - val_accuracy: 0.7000 - val_loss: 0.6037
# Epoch 25/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7667 - loss: 0.5610 - val_accuracy: 0.7000 - val_loss: 0.5910
# Epoch 26/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7667 - loss: 0.5477 - val_accuracy: 0.7000 - val_loss: 0.5795
# Epoch 27/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7750 - loss: 0.5357 - val_accuracy: 0.7000 - val_loss: 0.5691
# Epoch 28/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8000 - loss: 0.5247 - val_accuracy: 0.7000 - val_loss: 0.5596
# Epoch 29/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8083 - loss: 0.5147 - val_accuracy: 0.7000 - val_loss: 0.5508
# Epoch 30/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8083 - loss: 0.5053 - val_accuracy: 0.7000 - val_loss: 0.5425
# Epoch 31/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8083 - loss: 0.4965 - val_accuracy: 0.7000 - val_loss: 0.5344
# Epoch 32/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8083 - loss: 0.4883 - val_accuracy: 0.7000 - val_loss: 0.5266
# Epoch 33/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8167 - loss: 0.4806 - val_accuracy: 0.7000 - val_loss: 0.5190
# Epoch 34/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8167 - loss: 0.4733 - val_accuracy: 0.7000 - val_loss: 0.5117
# Epoch 35/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8167 - loss: 0.4664 - val_accuracy: 0.7000 - val_loss: 0.5046
# Epoch 36/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8167 - loss: 0.4598 - val_accuracy: 0.7000 - val_loss: 0.4976
# Epoch 37/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8167 - loss: 0.4535 - val_accuracy: 0.7333 - val_loss: 0.4909
# Epoch 38/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8167 - loss: 0.4475 - val_accuracy: 0.7333 - val_loss: 0.4845
# Epoch 39/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8167 - loss: 0.4417 - val_accuracy: 0.7333 - val_loss: 0.4785
# Epoch 40/40
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8250 - loss: 0.4361 - val_accuracy: 0.7333 - val_loss: 0.4727

# %% [markdown]
# ## 7. Graficar curvas de entrenamiento
#
# 1. Graficamos la función de pérdida (loss) en entrenamiento y validación.
# 2. Graficamos la exactitud (accuracy) en entrenamiento y validación.
#
# Interpretación: si la pérdida de entrenamiento baja pero la de validación sube, puede haber sobreajuste.

# %%
# 7. Graficar curvas de entrenamiento

def plot_history(history):
    plt.figure(figsize=(10, 4))

    # Pérdida
    plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"], label="train")
    plt.plot(history.history["val_loss"], label="val")
    plt.title("Pérdida")
    plt.xlabel("Época")
    plt.ylabel("Loss")
    plt.legend()

    # Exactitud
    plt.subplot(1, 2, 2)
    plt.plot(history.history["accuracy"], label="train")
    plt.plot(history.history["val_accuracy"], label="val")
    plt.title("Exactitud")
    plt.xlabel("Época")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)

# %% [markdown]
# ## 8. Evaluar el modelo en el conjunto de validación
#
# 1. Evaluamos el modelo con `model.evaluate` sobre `X_val, y_val`.
# 2. Obtenemos la pérdida (`loss`) y la exactitud (`accuracy`) finales en validación.

# %%
# 8. Evaluar el modelo en validación
loss, accuracy = model.evaluate(X_val, y_val, verbose=0)
print(f"Pérdida en validación: {loss:.4f}")
print(f"Exactitud en validación: {accuracy:.4f}")
# Out:
# Pérdida en validación: 0.4727
# Exactitud en validación: 0.7333

# %% [markdown]
# ## 9. Predicciones, métricas y matriz de confusión
#
# 1. Obtenemos probabilidades de cada clase con `model.predict`.
# 2. Convertimos las probabilidades a etiquetas predichas usando `argmax`.
# 3. Calculamos `classification_report`, `f1_score` promedio y la matriz de confusión.
# 4. Graficamos la matriz de confusión con etiquetas de clases.
#
# Mini–ejemplo de interpretación de `softmax`:
# - Si la salida es `[0.1, 0.7, 0.2]`, interpretamos 10 %, 70 % y 20 % de probabilidad para cada clase y elegimos la clase con probabilidad máxima (segunda clase).

# %%
# 9. Predicciones y métricas

# 9.1 Obtener probabilidades y clases predichas
y_proba = model.predict(X_val)
y_pred = np.argmax(y_proba, axis=1)

# 9.2 Métricas de clasificación
print("Reporte de clasificación:")
print(classification_report(y_val, y_pred, target_names=data.target_names))

macro_f1 = f1_score(y_val, y_pred, average="macro")
print(f"F1 macro: {macro_f1:.4f}")

# 9.3 Matriz de confusión
cm = confusion_matrix(y_val, y_pred)

plt.figure(figsize=(4, 4))
plt.imshow(cm, cmap="Blues")
plt.colorbar()
plt.xticks(range(3), data.target_names, rotation=45)
plt.yticks(range(3), data.target_names)
plt.xlabel("Etiqueta predicha")
plt.ylabel("Etiqueta real")
plt.title("Matriz de confusión")

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, cm[i, j], ha="center", va="center", color="black")

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Reporte de clasificación:
#               precision    recall  f1-score   support
#
#       setosa       0.91      1.00      0.95        10
#   versicolor       1.00      0.20      0.33        10
#    virginica       0.59      1.00      0.74        10
#
#     accuracy                           0.73        30
#    macro avg       0.83      0.73      0.68        30
# weighted avg       0.83      0.73      0.68        30
#
# F1 macro: 0.6755

# %% [markdown]
# ## 10. Guardar y cargar el modelo entrenado
#
# 1. Guardamos el modelo entrenado en disco para reutilizarlo sin reentrenar.
# 2. Cargamos el modelo desde el archivo y comprobamos que mantiene su rendimiento.
#
# Interpretación: `model.save` almacena arquitectura, pesos y configuración; `load_model` permite volver a usar el modelo más adelante para nuevas predicciones.

# %%
# 10. Guardar y cargar el modelo entrenado

# 10.1 Guardar el modelo en disco
model.save("modelo_iris_rna.keras")
print("Modelo guardado en 'modelo_iris_rna.keras'")

# 10.2 Cargar el modelo desde disco
modelo_cargado = keras.models.load_model("modelo_iris_rna.keras")

# Verificar que el modelo cargado funciona
loss_loaded, acc_loaded = modelo_cargado.evaluate(X_val, y_val, verbose=0)
print(f"Exactitud del modelo cargado en validación: {acc_loaded:.4f}")
# Out:
# Modelo guardado en 'modelo_iris_rna.keras'
# Exactitud del modelo cargado en validación: 0.7333

# %% [markdown]
# ## 11. Predicción para un nuevo ejemplo
#
# 1. Definimos manualmente las características de una nueva flor.
# 2. Aplicamos el mismo escalado usado en el entrenamiento.
# 3. Obtenemos las probabilidades `softmax` para cada clase.
# 4. Convertimos esas probabilidades en una clase predicha y mostramos el nombre de la especie.
#
# Mini–ejemplo: si la salida del `softmax` es `[0.95, 0.04, 0.01]`, interpretamos 95 %, 4 % y 1 % de probabilidad para cada clase y elegimos la clase con probabilidad máxima.

# %%
# 11. Predicción para un nuevo ejemplo

# 11.1 Definir una flor de ejemplo (valores típicos de setosa)
# [sepal_length, sepal_width, petal_length, petal_width]
nueva_flor = np.array([[5.7, 2.8, 4.1, 1.3]])

# 11.2 Aplicar el mismo escalado que al entrenamiento
nueva_flor_escalada = scaler.transform(nueva_flor)

# 11.3 Obtener probabilidades de clase
y_proba_nueva = model.predict(nueva_flor_escalada)
print("Probabilidades softmax:", y_proba_nueva)

# 11.4 Convertir a clase predicha y mostrar nombre
clase_predicha = np.argmax(y_proba_nueva, axis=1)[0]
nombre_clase = data.target_names[clase_predicha]

print(f"Clase predicha: {clase_predicha} -> {nombre_clase}")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B6B1A8AC00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Probabilidades softmax: [[0.2646243 0.4211804 0.3141953]]
# Clase predicha: 1 -> versicolor

# %% [markdown]
# ## 12. Mejorar entrenamiento con EarlyStopping
#
# 1. Usamos `EarlyStopping` para detener el entrenamiento cuando la pérdida de validación deje de mejorar.
# 2. Esto ayuda a evitar sobreentrenamiento y suele dejar el modelo en el punto de mejor `val_loss`.
# 3. Volvemos a entrenar un nuevo modelo desde cero usando este callback.

# %%
# 12. Mejorar entrenamiento con EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping

# 12.1 Crear un nuevo modelo desde cero
model_es = build_model(input_dim=X_train.shape[1], n_classes=3)

# 12.2 Definir callback de EarlyStopping
early_stop = EarlyStopping(
    monitor="val_loss",      # métrica a monitorear
    patience=5,               # número de épocas sin mejora antes de parar
    restore_best_weights=True # restaurar los mejores pesos obtenidos
)

# 12.3 Entrenar con EarlyStopping
history_es = model_es.fit(
    X_train,
    y_train,
    epochs=100,               # ponemos un máximo alto
    batch_size=16,
    validation_data=(X_val, y_val),
    callbacks=[early_stop],
    verbose=1
)

# 12.4 Evaluar modelo con EarlyStopping
loss_es, acc_es = model_es.evaluate(X_val, y_val, verbose=0)
print(f"Pérdida en validación (ES): {loss_es:.4f}")
print(f"Exactitud en validación (ES): {acc_es:.4f}")
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.3917 - loss: 1.0747 - val_accuracy: 0.5333 - val_loss: 1.0494
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6333 - loss: 1.0409 - val_accuracy: 0.6667 - val_loss: 1.0181
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7083 - loss: 1.0078 - val_accuracy: 0.7333 - val_loss: 0.9876
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7917 - loss: 0.9754 - val_accuracy: 0.7667 - val_loss: 0.9572
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8167 - loss: 0.9429 - val_accuracy: 0.8000 - val_loss: 0.9276
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8417 - loss: 0.9094 - val_accuracy: 0.8000 - val_loss: 0.8987
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8500 - loss: 0.8759 - val_accuracy: 0.8000 - val_loss: 0.8702
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8500 - loss: 0.8427 - val_accuracy: 0.8000 - val_loss: 0.8424
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8583 - loss: 0.8103 - val_accuracy: 0.7667 - val_loss: 0.8150
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8583 - loss: 0.7787 - val_accuracy: 0.7667 - val_loss: 0.7876
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8583 - loss: 0.7477 - val_accuracy: 0.7667 - val_loss: 0.7599
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8583 - loss: 0.7166 - val_accuracy: 0.7667 - val_loss: 0.7316
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8750 - loss: 0.6857 - val_accuracy: 0.8000 - val_loss: 0.7033
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8750 - loss: 0.6546 - val_accuracy: 0.8333 - val_loss: 0.6747
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8833 - loss: 0.6237 - val_accuracy: 0.8333 - val_loss: 0.6460
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8833 - loss: 0.5931 - val_accuracy: 0.8333 - val_loss: 0.6174
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8917 - loss: 0.5627 - val_accuracy: 0.8333 - val_loss: 0.5892
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9083 - loss: 0.5326 - val_accuracy: 0.8333 - val_loss: 0.5616
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9167 - loss: 0.5032 - val_accuracy: 0.8667 - val_loss: 0.5348
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9167 - loss: 0.4747 - val_accuracy: 0.8667 - val_loss: 0.5091
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9250 - loss: 0.4473 - val_accuracy: 0.8667 - val_loss: 0.4846
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9333 - loss: 0.4210 - val_accuracy: 0.8667 - val_loss: 0.4616
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9417 - loss: 0.3961 - val_accuracy: 0.8667 - val_loss: 0.4402
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9417 - loss: 0.3728 - val_accuracy: 0.8667 - val_loss: 0.4199
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9417 - loss: 0.3513 - val_accuracy: 0.8667 - val_loss: 0.4007
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9417 - loss: 0.3314 - val_accuracy: 0.8667 - val_loss: 0.3828
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9417 - loss: 0.3132 - val_accuracy: 0.8667 - val_loss: 0.3663
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9417 - loss: 0.2965 - val_accuracy: 0.8667 - val_loss: 0.3509
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9417 - loss: 0.2811 - val_accuracy: 0.8667 - val_loss: 0.3369
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9417 - loss: 0.2669 - val_accuracy: 0.9000 - val_loss: 0.3237
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9500 - loss: 0.2539 - val_accuracy: 0.9000 - val_loss: 0.3116
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9500 - loss: 0.2419 - val_accuracy: 0.9000 - val_loss: 0.3005
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9500 - loss: 0.2308 - val_accuracy: 0.9000 - val_loss: 0.2900
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9500 - loss: 0.2206 - val_accuracy: 0.9000 - val_loss: 0.2802
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.2112 - val_accuracy: 0.9000 - val_loss: 0.2710
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.2024 - val_accuracy: 0.9000 - val_loss: 0.2625
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1943 - val_accuracy: 0.9000 - val_loss: 0.2547
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9667 - loss: 0.1866 - val_accuracy: 0.9000 - val_loss: 0.2472
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.1794 - val_accuracy: 0.9000 - val_loss: 0.2400
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1726 - val_accuracy: 0.9000 - val_loss: 0.2333
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1663 - val_accuracy: 0.9333 - val_loss: 0.2269
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9667 - loss: 0.1604 - val_accuracy: 0.9333 - val_loss: 0.2209
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1548 - val_accuracy: 0.9333 - val_loss: 0.2151
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.1497 - val_accuracy: 0.9333 - val_loss: 0.2095
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1448 - val_accuracy: 0.9333 - val_loss: 0.2044
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1402 - val_accuracy: 0.9333 - val_loss: 0.1994
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1358 - val_accuracy: 0.9333 - val_loss: 0.1947
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1317 - val_accuracy: 0.9333 - val_loss: 0.1902
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.1278 - val_accuracy: 0.9333 - val_loss: 0.1859
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1241 - val_accuracy: 0.9333 - val_loss: 0.1817
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9667 - loss: 0.1206 - val_accuracy: 0.9333 - val_loss: 0.1777
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1173 - val_accuracy: 0.9333 - val_loss: 0.1739
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9667 - loss: 0.1142 - val_accuracy: 0.9333 - val_loss: 0.1702
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.1112 - val_accuracy: 0.9333 - val_loss: 0.1666
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.1084 - val_accuracy: 0.9333 - val_loss: 0.1633
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9667 - loss: 0.1058 - val_accuracy: 0.9333 - val_loss: 0.1601
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1032 - val_accuracy: 0.9333 - val_loss: 0.1570
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.1009 - val_accuracy: 0.9333 - val_loss: 0.1541
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0986 - val_accuracy: 0.9333 - val_loss: 0.1514
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0964 - val_accuracy: 0.9333 - val_loss: 0.1488
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0944 - val_accuracy: 0.9333 - val_loss: 0.1462
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0924 - val_accuracy: 0.9333 - val_loss: 0.1438
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9667 - loss: 0.0905 - val_accuracy: 0.9333 - val_loss: 0.1416
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0887 - val_accuracy: 0.9333 - val_loss: 0.1394
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0870 - val_accuracy: 0.9333 - val_loss: 0.1373
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0854 - val_accuracy: 0.9333 - val_loss: 0.1352
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0838 - val_accuracy: 0.9333 - val_loss: 0.1333
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0823 - val_accuracy: 0.9333 - val_loss: 0.1315
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0809 - val_accuracy: 0.9333 - val_loss: 0.1298
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9667 - loss: 0.0795 - val_accuracy: 0.9333 - val_loss: 0.1281
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0781 - val_accuracy: 0.9333 - val_loss: 0.1265
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0768 - val_accuracy: 0.9333 - val_loss: 0.1249
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0756 - val_accuracy: 0.9333 - val_loss: 0.1235
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0744 - val_accuracy: 0.9333 - val_loss: 0.1221
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0733 - val_accuracy: 0.9333 - val_loss: 0.1207
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0722 - val_accuracy: 0.9333 - val_loss: 0.1194
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0711 - val_accuracy: 0.9333 - val_loss: 0.1182
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0701 - val_accuracy: 0.9333 - val_loss: 0.1170
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0691 - val_accuracy: 0.9333 - val_loss: 0.1158
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0681 - val_accuracy: 0.9333 - val_loss: 0.1147
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0672 - val_accuracy: 0.9333 - val_loss: 0.1136
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0663 - val_accuracy: 0.9333 - val_loss: 0.1125
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0655 - val_accuracy: 0.9333 - val_loss: 0.1114
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0646 - val_accuracy: 0.9333 - val_loss: 0.1105
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9667 - loss: 0.0638 - val_accuracy: 0.9333 - val_loss: 0.1095
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9667 - loss: 0.0630 - val_accuracy: 0.9333 - val_loss: 0.1086
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0623 - val_accuracy: 0.9333 - val_loss: 0.1077
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0616 - val_accuracy: 0.9333 - val_loss: 0.1069
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0608 - val_accuracy: 0.9333 - val_loss: 0.1061
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9667 - loss: 0.0602 - val_accuracy: 0.9333 - val_loss: 0.1052
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9750 - loss: 0.0595 - val_accuracy: 0.9333 - val_loss: 0.1044
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9750 - loss: 0.0589 - val_accuracy: 0.9333 - val_loss: 0.1038
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9750 - loss: 0.0582 - val_accuracy: 0.9333 - val_loss: 0.1031
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9750 - loss: 0.0576 - val_accuracy: 0.9333 - val_loss: 0.1024
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9750 - loss: 0.0570 - val_accuracy: 0.9333 - val_loss: 0.1016
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9750 - loss: 0.0565 - val_accuracy: 0.9333 - val_loss: 0.1009
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9750 - loss: 0.0559 - val_accuracy: 0.9333 - val_loss: 0.1003
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9750 - loss: 0.0554 - val_accuracy: 0.9333 - val_loss: 0.0997
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9750 - loss: 0.0549 - val_accuracy: 0.9333 - val_loss: 0.0991
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9750 - loss: 0.0543 - val_accuracy: 0.9333 - val_loss: 0.0985
# Pérdida en validación (ES): 0.0985
# Exactitud en validación (ES): 0.9333

# %% [markdown]
# ## 13. Comparar la RNA con un modelo clásico (Regresión Logística)
#
# 1. Entrenamos una Regresión Logística sobre los mismos datos escalados.
# 2. Comparamos la exactitud y el F1 macro entre la RNA con EarlyStopping y la Regresión Logística.
# 3. Esto nos sirve como referencia para saber si la RNA está rindiendo tan bien como un modelo clásico fuerte en este dataset.

# %%
# 13. Comparar con Regresión Logística
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# 13.1 Entrenar Regresión Logística
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)

# 13.2 Evaluar en validación
y_pred_lr = log_reg.predict(X_val)
acc_lr = accuracy_score(y_val, y_pred_lr)
macro_f1_lr = f1_score(y_val, y_pred_lr, average="macro")

print(f"Accuracy Regresión Logística: {acc_lr:.4f}")
print(f"F1 macro Regresión Logística: {macro_f1_lr:.4f}")

# 13.3 Comparar con la RNA (EarlyStopping)
y_proba_es = model_es.predict(X_val)
y_pred_es = np.argmax(y_proba_es, axis=1)

macro_f1_es = f1_score(y_val, y_pred_es, average="macro")
print(f"F1 macro RNA (EarlyStopping): {macro_f1_es:.4f}")
# Out:
# Accuracy Regresión Logística: 0.9333
# F1 macro Regresión Logística: 0.9333
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B6AE846AC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# F1 macro RNA (EarlyStopping): 0.9333

# %% [markdown]
# ## 14. Resumen de mejoras aplicadas
#
# 1. Agregamos `EarlyStopping` para detener el entrenamiento cuando la validación deja de mejorar.
# 2. Comparamos el desempeño de la RNA contra Regresión Logística en el mismo conjunto de validación.
# 3. Con estos pasos puedes:
#    - Ajustar arquitectura e hiperparámetros de la RNA.
#    - Ver si tiene sentido usar una RNA o si un modelo clásico ya alcanza un rendimiento similar o mejor.
