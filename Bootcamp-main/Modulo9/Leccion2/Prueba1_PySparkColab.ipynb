# %% [markdown]
# **Verificar que PySpark corre**

# %%
#!pip install pyspark -q

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("PruebaColabPySpark") \
    .getOrCreate()

print(spark)

# %% [markdown]
# **Probar volumen “mediano” generado en el mismo notebook**

# %%
n = 5_000_000

df = spark.range(0, n)
print(df.count())
df.show(5)
# Out:
# 5000000
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+
# only showing top 5 rows

# %% [markdown]
# **Medir una operación más pesada**

# %%
from pyspark.sql.functions import col

resultado = (
    df.withColumn("grupo", col("id") % 10)
      .groupBy("grupo")
      .count()
)

resultado.show()
# Out:
# +-----+------+
# |grupo| count|
# +-----+------+
# |    0|500000|
# |    7|500000|
# |    6|500000|
# |    9|500000|
# |    5|500000|
# |    1|500000|
# |    3|500000|
# |    8|500000|
# |    2|500000|
# |    4|500000|
# +-----+------+

# %%
import time

start = time.time()
print(df.count())
print("Tiempo count:", round(time.time() - start, 2), "segundos")
# Out:
# 5000000
# Tiempo count: 0.24 segundos
